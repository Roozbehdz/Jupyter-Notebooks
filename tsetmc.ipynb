# %%
from tehran_stocks import get_all_price
get_all_price()
# Out:
# No database founded.
# creating database
# making database folder ...
# DataBase created in: /home/roozbehdz/tse
# downloding  stock name and details from tccim
# may take few minutes
# ...
# downloading group: 41, changes: 45.2% completeddownloading group: 41, changes: 45.9% completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-98c6a0337600> in <module>
# ----> 1 from tehran_stocks import get_all_price
#       2 get_all_price()
#
# ~/anaconda3/lib/python3.7/site-packages/tehran_stocks/__init__.py in <module>
#      17     print("No database founded.")
#      18     init_db()
# ---> 19     fill_db()
#
# ~/anaconda3/lib/python3.7/site-packages/tehran_stocks/initializer.py in fill_db()
#      19     print("downloding  stock name and details from tccim")
#      20     print("may take few minutes ")
# ---> 21     fill_stock_table()
# ...
